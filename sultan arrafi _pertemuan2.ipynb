# %%
 a = [1,2,3]
 b = [ 4,5,6 ]

 hasil = a + b
 print(hasil)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
def totallist(a, b):
  total = 0
  for i in a:
    total += i
  for i in b:
      total += i
  return total

  a = [1,2,3]
  b = [4,5,6]

  result = totallist(a, b)
  print(result)

# %%
print("hello world")
print("nama saya arrafi")
print("nim saya 2023071060")
# Out:
# hello world
# nama saya arrafi
# nim saya 2023071060

# %%
Nama = input ("Masukan Nama")
Nim = input("Masukan Nim")
print("Nama saya",Nama)
print("Nim saya",Nim)
# Out:
# Masukan Namarafi
# Masukan Nim2023071060
# Nama saya rafi
# Nim saya 2023071060

# %%
if 5>2:
  print ("katakata")
# Out:
# katakata

# %%
mylist = [1, 2, 3, 4, 5]

getfirst = mylist[0]
getsecond = mylist[1]

print("first element:", getfirst)
print("second element:", getsecond)
# Out:
# first element: 1
# second element: 2

# %%
def getlist(list):
    size = len(list)
    print (size)
    return list[size-1]
